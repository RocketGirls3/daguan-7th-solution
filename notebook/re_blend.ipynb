# %%
import pandas as pd
import numpy as np

# %%
result1 = pd.read_csv('../10fold_pro/prob_rnn_baseline4.csv')
result2 = pd.read_csv('../pro/prescore_779.csv')
result3 = pd.read_csv('../pro/prob_ridge_baseline4.csv')
result4 = pd.read_csv('../pro/prob_lgb_baseline4.csv')
result5 = pd.read_csv('../10fold_pro/prob_cnn_baseline.csv')
result6 = pd.read_csv('../output/prob_fm_baseline.csv')
result7 = pd.read_csv('../10fold_pro/prob_Capsule_baseline.csv')
result8 = pd.read_csv('../pro/prob_rnn_cnn_baseline.csv')

result11 = pd.read_csv('../pro/prob_rnn_shufflte.csv')
result9 = pd.read_csv('../pro/prob_capsule_shufflte.csv')
resultx = pd.read_csv('../pro/rnn_pesudoss.csv')
result14 = pd.read_csv('../pro/prob_capsule_shuffle_all.csv')
result15 = pd.read_csv('../pro/prob_rnn_shuffle_all.csv')

# %%
for i in range(1,20):
    result2["class_prob_{}".format(i)] = (result8["class_prob_{}".format(i)]+result14["class_prob_{}".format(i)] + result14["class_prob_{}".format(i)] + result6["class_prob_{}".format(i)] + result6["class_prob_{}".format(i)] + result5["class_prob_{}".format(i)] + result4["class_prob_{}".format(i)] +result3["class_prob_{}".format(i)] + result2["class_prob_{}".format(i)] + result3["class_prob_{}".format(i)] + result2["class_prob_{}".format(i)] + result15["class_prob_{}".format(i)] + result15["class_prob_{}".format(i)] + resultx["class_prob_{}".format(i)])/14
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
result2.to_csv('all_blend_file5.csv', index=False)

# %%
preds=np.argmax(result2[name].values,axis=1)
test_pred=pd.DataFrame(preds)
test_pred.columns=["class"]
test_pred["class"]=(test_pred["class"]+1).astype(int)
test_pred["id"]=list(result2["id"])
test_pred[["id","class"]].to_csv('../blend_output/re_blend5.csv',index=None)
# result2["class_prob_{}".format(i)] = (result8["class_prob_{}".format(i)]+result9["class_prob_{}".format(i)] + result9["class_prob_{}".format(i)] + result6["class_prob_{}".format(i)] + result6["class_prob_{}".format(i)] + result5["class_prob_{}".format(i)] + result4["class_prob_{}".format(i)] +result3["class_prob_{}".format(i)] + result2["class_prob_{}".format(i)] + result3["class_prob_{}".format(i)] + result2["class_prob_{}".format(i)] + result1["class_prob_{}".format(i)] + result1["class_prob_{}".format(i)] + result1["class_prob_{}".format(i)])/14

# %%
test_pred
# Out:
#         class      id
# 0           5       0
# 1           4       1
# 2          13       2
# 3           4       3
# 4           5       4
# 5           5       5
# 6          15       6
# 7          19       7
# 8           3       8
# 9          12       9
# 10          8      10
# 11          1      11
# 12          5      12
# 13         13      13
# 14         15      14
# 15         18      15
# 16          9      16
# 17          9      17
# 18          3      18
# 19         14      19
# 20          9      20
# 21         11      21
# 22          9      22
# 23          9      23
# 24          2      24
# 25         15      25
# 26          3      26
# 27         15      27
# 28          4      28
# 29         19      29
# ...       ...     ...
# 102247     16  102247
# 102248      8  102248
# 102249     10  102249
# 102250      2  102250
# 102251     18  102251
# 102252     16  102252
# 102253     18  102253
# 102254      2  102254
# 102255     14  102255
# ...

# %%
result2
# Out:
#         class_prob_1  class_prob_2  class_prob_3  class_prob_4  class_prob_5  \
# 0          -0.019608     -0.009801      0.012360      0.014106      0.964727
# 1           0.042342      0.015658     -0.000568      0.911826      0.003029
# 2           0.033210      0.003398      0.126259      0.011286      0.023681
# 3           0.018738     -0.006553      0.006745      0.999709      0.003994
# 4           0.062963     -0.011264     -0.002965      0.003718      0.871257
# 5           0.029341      0.013994      0.014026      0.024834      0.748788
# 6           0.025101     -0.009510      0.032713      0.019254     -0.006157
# 7           0.051283      0.127976      0.019940      0.015978      0.004947
# 8           0.000792     -0.000108      0.962156      0.002850      0.000950
# 9           0.097680      0.014896     -0.025712      0.007551     -0.009511
# 10          0.093602     -0.011386     -0.001233     -0.011545     -0.008999
# ...
